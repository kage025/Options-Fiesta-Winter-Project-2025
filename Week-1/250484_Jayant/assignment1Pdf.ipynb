# %% [markdown]
# #1

# %%
import numpy as np

# %%
arr = np.random.randint(1, 10, size = 10)
print(arr)
print(f"max:{arr.max()}\nmin:{arr.min()}")
# Out:
# [5 7 6 8 8 1 2 7 3 3]
# max:8
# min:1

# %% [markdown]
# #2

# %%
s = 'helleh'

True if s == s[::-1] else False
# Out:
# True

# %% [markdown]
# #3

# %%
arr = np.random.randint(1, 10, size = 10)
print(arr)
x = 1
for i in arr:
    for j in arr:
        if i-j == x:
            print(i, j)
# Out:
# [4 8 7 1 5 1 3 9 6 4]
# 4 3
# 8 7
# 7 6
# 5 4
# 5 4
# 9 8
# 6 5
# 4 3
